# %% [markdown]
# # Using YOLOv3-tiny and OpenCV 4 to detect objects
#
# I wanted to try to use OpenCV and YoloV3 in order to detect basics objects, this is what this notebook will be about.
#
# *Thank you Joseph Redmon and Ali Farhadi for their incredible work on YOLO object detector* : **YOLOv3: An Incremental Improvement**, *Redmon, Joseph and Farhadi, Ali* ; arXiv, 2018.
#
# This paper was my main inspiration for this notebook.

# %%
# import useful libraries
import os
import numpy as np
import cv2
print('OpenCV version : ', cv2. __version__)
# Out:
# OpenCV version :  4.5.1

# %% [markdown]
# ### Load YoloV3 models with pre-trained weights

# %%
# function to load our classes names
def read_classes(file):
    """ Read the classes files and extract the classes' names in it""" 
    classNames = []    
    with open(file, 'rt') as f:
        classNames = f.read().rstrip('\n').split('\n')
   
    return classNames

# %%
# test our function read_classes
img_file = './data/coco.names'
classNames = read_classes(img_file)
# classNames

# %% [markdown]
# ### YoloV3-tiny weights and cfg files
#
# In this part we'll upload YoloV3 Weights and cfg files in order to input them into ***cv2.dnn.readNetFromDarknet()*** and build our forward propagation with OpenCV.

# %%
# load the model config and weights
modelConfig_path = './cfg/yolov3-tiny.cfg'
modelWeights_path = './models/yolov3-tiny.weights'

# read the model cfg and weights with the cv2 DNN module
neural_net = cv2.dnn.readNetFromDarknet(modelConfig_path, modelWeights_path)
# set the preferable Backend to GPU
neural_net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
neural_net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

# confidence and non-max suppression threshold for this YoloV3 version
confidenceThreshold = 0.3
nmsThreshold = 0.1

# %% [markdown]
# ## Function creation for object detection
#
# In this part, we'll define the object detection function which allows us to get **the output of the three YOLO layers (82,94,106)** and select **the best bounding box** to put on the detected object, the layers' outputs are in the format :
# - The confidence probability (if there is an object or not in the frame)
# - (x,y) coordinates of the center of the object
# - (height, width) of the frame
# - All the scores of the detected object (if there is an object detected, which one is it?)
#
# We know that the first 5 elements of the results ouputs are not the "scores", **i.e.** : *the 80 classes probabilities of what kind of object is detected*. That's why we'll start to store our outputs layers' values in different lists, the first one will stock all the **scores** from the fifth element to the last element (80th), then we'll collect the first 5 elements.
#
# For the 5th to 80th elements corresponding to *the objects scores*, we'll take the maximum value which will represent the **highest probability** about what's the object's class.
#
# #### Object detection function
#
# Based on what we've detailed above, we'll write an object detection function.

# %%
def object_detection(outputs, input_frame):
    """ This function will allow us to draw bounding boxes on detected objects in frames (images) """
    # first we'll collect the height, width and channel of the input frame (3 if the image is RGB, 1 if it's grayscale)
    height, width, channel = input_frame.shape
    
    # we'll create category lists to store the layers' output values 
    bounding_boxes = []
    class_objects = []
    confidence_probs = []
    
    # Knowing that there are 3 YOLO layers, we'll browsing them and their outputs using this :
    for result in outputs:        
        for values in result:
            
            scores = values[5:] # we know that the class probabilities are from the 5th values
            indices_object = np.argmax(scores) # get the indice of the max score
            confidence_probability = scores[indices_object] # store the maximum value of the indice found
            
            # in order to have a proper detection, we'll eliminate the weakest probability detection by imposing a threshold
            if confidence_probability > confidenceThreshold:   
                
                # get the pixel values corresponding to the scaling of the bounding box coordinates to the initial frame
                box_detected = values[0:4] * np.array([width, height, width, height])                                 
                # get the top left corner coordinates by extracting values from box_detected and perform calculations
                x, y, w, h = box_detected
                # we're converting the coordinates to int because OpenCV doesn't allow floats for bounding boxes
                x = int(x - (w/2))
                y = int(y - (h/2))
                
                # adding the good detected boxe in the bounding boxes list created
                bounding_boxes.append([x,y,w,h])                
                # adding the detected objects indices in the class objects list 
                class_objects.append(indices_object)                
                # adding the max value of the object score (confidence) in the confidences_probs list
                confidence_probs.append(float(confidence_probability))    
    
    return bounding_boxes, class_objects, confidence_probs

# %% [markdown]
# #### Non-max suppresion function
#
# When we're doing object detection with YoloV3, the algorithm outputs several bounding boxes. In order to keep the best bounding box we'll need to perform a maximizimation technique called **non-max suppression**, this method will allow us to keep the bounding box with the highest probability and eliminate the others.

# %%
def nms_bbox(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold):
    """This function performs non-max suppression on all the bounding boxes detected and keeps the best one"""    
    #Using OpenCV DNN non-max supression to get the best bounding box of the detected object (retrieve the indices)
    indices_bbox = cv2.dnn.NMSBoxes(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold)   
    print('Number of objects detected : ', len(indices_bbox), '\n')
    
    return indices_bbox

# %% [markdown]
# #### Drawing box function
#
# Now, we have only one bounding box left (the best one) and we'll just need to draw the corresponding box.

# %%
def box_drawing(input_frame, indices, bounding_boxes, class_objects, confidence_probs, classNames, color=(0,255,255), thickness=2):
    """ Drawing the detected objects boxes """
    # once we have the indices, we'll extract the values of x,y,w,h of the best bounding boxes and stores it.
    for i in indices:
        i = i[0]
        final_box = bounding_boxes[i]
    # we'll retrieve the bounding boxes values (coordinates) now and use them to draw our boxes.
        x, y, w, h = final_box[0], final_box[1], final_box[2], final_box[3]
        x, y, w, h = int(x), int(y), int(w), int(h)        
        print('Bounding box coordinates in the frame : ', 'x : ', x,'|| y : ',y,'|| w : ',w,'|| h :',h , '\n')
    
        cv2.rectangle(input_frame, (x,y), (x+w,y+h),  (0, 255, 255), 2)
        cv2.putText(input_frame, f'{classNames[class_objects[i]].upper()} {int(confidence_probs[i]*100)}%',
                        (x, y-10), cv2.FONT_HERSHEY_DUPLEX, 0.6,  (0, 255, 255), 2)

# %% [markdown]
# ####  Blob function
#
# OpenCV uses blob techniques to extract features from an image and allows detection. In order to be able to do forward propagation on our images or videos, we'll need to convert our images to **OpenCV blob's format**.

# %%
def convert_to_blob(input_frame, network, height, width):
    """ This function allow us to convert a frame/image into blob format for OpenCV DNN"""    
    blob = cv2.dnn.blobFromImage(input_frame, 1/255, (height,width), [0,0,0], 1, crop=False)
    network.setInput(blob)
    # get the YOLO output layers numbers (names), these layers will be useful for the detection part
    # the layer's name : yolo_82, yolo_94, yolo_106
    yoloLayers = network.getLayerNames()
    outputLayers = [(yoloLayers[i[0]-1]) for i in network.getUnconnectedOutLayers()]
    # Doing forward propagation with OpenCV
    outputs = network.forward(outputLayers)
    
    return outputs

# %% [markdown]
# ### Test on video files

# %%
# method to load our video from directory
import os 

def load_video(video):    
    """ Return the video by inputing the title of the video """ 
    # get the video path and load the video
    video_path = os.path.join('videos', video)
    
    return video_path

# %%
cap_video = cv2.VideoCapture(load_video('library1.mp4'))

network = neural_net
# we can decrease the height and width but the minimum is 320x320.
height, width = 600,600

while cap_video.isOpened():
    success, video_frames = cap_video.read()
    # if 'video_frames' is read correctly 'success' is True
    if not success:
        print("Can't receive frame (stream end?). Exiting ...")
        break
        
    # using convert_to_blob function : 
    outputs = convert_to_blob(video_frames, network, height, width)    
    # apply object detection on the video file
    bounding_boxes, class_objects, confidence_probs = object_detection(outputs, video_frames)   
    # perform non-max suppression
    indices = nms_bbox(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold)
    # draw the boxes
    box_drawing(video_frames, indices, bounding_boxes, class_objects, confidence_probs, classNames, color=(0,255,255), thickness=2)
  
    cv2.imshow('Object Detection in videos', video_frames)
    
    if cv2.waitKey(1) == ord('q'):
        break
        
cap_video.release()
cv2.destroyAllWindows()
# Out:
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  415 || y :  471 || w :  177 || h : 319
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  387 || y :  473 || w :  177 || h : 336
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  383 || y :  478 || w :  173 || h : 323
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  374 || y :  465 || w :  195 || h : 352
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  372 || y :  458 || w :  195 || h : 355
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  367 || y :  452 || w :  193 || h : 377
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  350 || y :  459 || w :  186 || h : 371
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  364 || y :  478 || w :  197 || h : 361
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  366 || y :  471 || w :  199 || h : 374
#
# Bounding box coordinates in the frame :  x :  248 || y :  494 || w :  83 || h : 158
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  377 || y :  476 || w :  197 || h : 379
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  322 || y :  653 || w :  314 || h : 257
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  367 || y :  480 || w :  232 || h : 400
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  388 || y :  471 || w :  193 || h : 417
#
# Bounding box coordinates in the frame :  x :  128 || y :  475 || w :  81 || h : 176
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  411 || y :  463 || w :  195 || h : 440
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  410 || y :  466 || w :  203 || h : 437
#
# Bounding box coordinates in the frame :  x :  49 || y :  469 || w :  86 || h : 173
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  410 || y :  450 || w :  203 || h : 470
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  411 || y :  451 || w :  203 || h : 475
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  387 || y :  472 || w :  236 || h : 439
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  392 || y :  451 || w :  227 || h : 478
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  380 || y :  479 || w :  200 || h : 419
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  356 || y :  484 || w :  244 || h : 410
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  349 || y :  480 || w :  195 || h : 414
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  338 || y :  478 || w :  206 || h : 337
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  300 || y :  464 || w :  254 || h : 361
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  296 || y :  488 || w :  221 || h : 401
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  288 || y :  486 || w :  214 || h : 401
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  265 || y :  476 || w :  203 || h : 343
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  251 || y :  464 || w :  211 || h : 366
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  233 || y :  475 || w :  193 || h : 335
#
# Bounding box coordinates in the frame :  x :  126 || y :  738 || w :  229 || h : 191
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  221 || y :  469 || w :  206 || h : 365
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  197 || y :  467 || w :  192 || h : 365
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  189 || y :  463 || w :  203 || h : 363
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  177 || y :  467 || w :  200 || h : 333
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  156 || y :  478 || w :  194 || h : 332
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  141 || y :  466 || w :  199 || h : 359
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  135 || y :  472 || w :  202 || h : 335
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  111 || y :  483 || w :  197 || h : 318
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  97 || y :  482 || w :  201 || h : 327
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  77 || y :  484 || w :  196 || h : 313
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  481 || w :  195 || h : 321
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  44 || y :  478 || w :  188 || h : 321
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  23 || y :  479 || w :  198 || h : 326
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  0 || y :  643 || w :  237 || h : 223
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  3 || y :  485 || w :  179 || h : 323
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -6 || y :  487 || w :  182 || h : 317
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -2 || y :  474 || w :  148 || h : 345
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  2 || y :  480 || w :  131 || h : 322
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  0 || y :  477 || w :  122 || h : 326
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  37 || y :  664 || w :  56 || h : 124
#
# Bounding box coordinates in the frame :  x :  640 || y :  563 || w :  25 || h : 12
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  3 || y :  608 || w :  93 || h : 217
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  0 || y :  598 || w :  80 || h : 224
#
# Bounding box coordinates in the frame :  x :  370 || y :  550 || w :  9 || h : 32
#
# Bounding box coordinates in the frame :  x :  681 || y :  576 || w :  13 || h : 18
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  0 || y :  602 || w :  67 || h : 212
#
# Bounding box coordinates in the frame :  x :  645 || y :  570 || w :  15 || h : 15
#
# Bounding box coordinates in the frame :  x :  333 || y :  546 || w :  10 || h : 34
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  6 || y :  687 || w :  33 || h : 71
#
# Bounding box coordinates in the frame :  x :  683 || y :  569 || w :  16 || h : 22
#
# Bounding box coordinates in the frame :  x :  302 || y :  544 || w :  11 || h : 31
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  267 || y :  543 || w :  10 || h : 33
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  607 || y :  592 || w :  101 || h : 110
#
# Bounding box coordinates in the frame :  x :  237 || y :  545 || w :  11 || h : 34
#
# Number of objects detected :  6
#
# Bounding box coordinates in the frame :  x :  590 || y :  749 || w :  123 || h : 142
#
# Bounding box coordinates in the frame :  x :  208 || y :  544 || w :  10 || h : 36
#
# Bounding box coordinates in the frame :  x :  100 || y :  540 || w :  12 || h : 21
#
# Bounding box coordinates in the frame :  x :  253 || y :  549 || w :  13 || h : 31
#
# Bounding box coordinates in the frame :  x :  282 || y :  259 || w :  31 || h : 12
#
# Bounding box coordinates in the frame :  x :  596 || y :  582 || w :  116 || h : 121
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  178 || y :  539 || w :  10 || h : 36
# Bounding box coordinates in the frame :  x :  560 || y :  750 || w :  135 || h : 132
#
# Bounding box coordinates in the frame :  x :  560 || y :  578 || w :  136 || h : 116
#
# Bounding box coordinates in the frame :  x :  228 || y :  547 || w :  13 || h : 30
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  193 || y :  549 || w :  12 || h : 31
#
# Bounding box coordinates in the frame :  x :  150 || y :  539 || w :  9 || h : 36
#
# Bounding box coordinates in the frame :  x :  538 || y :  718 || w :  162 || h : 134
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  120 || y :  541 || w :  10 || h : 35
#
# Bounding box coordinates in the frame :  x :  496 || y :  577 || w :  116 || h : 99
#
# Bounding box coordinates in the frame :  x :  171 || y :  549 || w :  12 || h : 27
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  138 || y :  550 || w :  12 || h : 28
#
# Bounding box coordinates in the frame :  x :  93 || y :  542 || w :  8 || h : 35
#
# Bounding box coordinates in the frame :  x :  479 || y :  577 || w :  137 || h : 107
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  489 || y :  597 || w :  59 || h : 61
#
# Bounding box coordinates in the frame :  x :  112 || y :  545 || w :  13 || h : 30
#
# Bounding box coordinates in the frame :  x :  61 || y :  538 || w :  11 || h : 34
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  448 || y :  593 || w :  64 || h : 66
#
# Bounding box coordinates in the frame :  x :  73 || y :  541 || w :  27 || h : 40
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  403 || y :  580 || w :  135 || h : 98
#
# Bounding box coordinates in the frame :  x :  60 || y :  543 || w :  12 || h : 31
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  414 || y :  592 || w :  60 || h : 62
#
# Bounding box coordinates in the frame :  x :  38 || y :  545 || w :  11 || h : 31
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  396 || y :  599 || w :  58 || h : 53
#
# Bounding box coordinates in the frame :  x :  15 || y :  542 || w :  10 || h : 33
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  367 || y :  591 || w :  52 || h : 59
#
# Bounding box coordinates in the frame :  x :  322 || y :  653 || w :  303 || h : 220
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  341 || y :  592 || w :  55 || h : 58
#
# Bounding box coordinates in the frame :  x :  310 || y :  728 || w :  105 || h : 125
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  336 || y :  593 || w :  61 || h : 58
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  320 || y :  590 || w :  60 || h : 54
#
# Bounding box coordinates in the frame :  x :  274 || y :  732 || w :  107 || h : 118
#
# Can't receive frame (stream end?). Exiting ...
