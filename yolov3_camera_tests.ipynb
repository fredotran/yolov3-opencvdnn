# %% [markdown]
# # Using YOLOv3 and OpenCV 4 to detect objects
#
# I wanted to try to use OpenCV and YoloV3 in order to detect basics objects, this is what this notebook will be about.
#
# *Thank you Joseph Redmon and Ali Farhadi for their incredible work on YOLO object detector* : **YOLOv3: An Incremental Improvement**, *Redmon, Joseph and Farhadi, Ali* ; arXiv, 2018.
#
# This paper was my main inspiration for this notebook.

# %%
# import useful libraries
import os
import numpy as np
import cv2
print('OpenCV version : ', cv2. __version__)
# Out:
# OpenCV version :  4.5.1

# %% [markdown]
# ### Load YoloV3 models with pre-trained weights

# %%
# function to load our classes names
def read_classes(file):
    """ Read the classes files and extract the classes' names in it""" 
    classNames = []    
    with open(file, 'rt') as f:
        classNames = f.read().rstrip('\n').split('\n')
   
    return classNames

# %%
# read the file with the classes names
img_file = './data/coco.names'
classNames = read_classes(img_file)
#classNames

# %% [markdown]
# ### YoloV3 weights and cfg files
#
# In this part we'll upload YoloV3 Weights and cfg files in order to input them into cv2.dnn.readNetFromDarknet() and build our forward propagation with OpenCV. The weights and configs can be downloaded at : https://pjreddie.com/darknet/yolo/

# %%
# load the model config and weights
modelConfig_path = './cfg/yolov3.cfg'
modelWeights_path = './models/yolov3-320.weights'

# read the model cfg and weights with the cv2 DNN module
neural_net = cv2.dnn.readNetFromDarknet(modelConfig_path, modelWeights_path)
# set the preferable Backend to GPU
neural_net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
neural_net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

# confidence and non-max suppression threshold for this YoloV3 version
confidenceThreshold = 0.3
nmsThreshold = 0.2

# %% [markdown]
# ## Function creation for object detection
#
# In this part, we'll define the object detection function which allows us to get **the output of the three YOLO layers (82,94,106)** and select **the best bounding box** to put on the detected object, the layers' outputs are in the format :
# - The confidence probability (if there is an object or not in the frame)
# - (x,y) coordinates of the center of the object
# - (height, width) of the frame
# - All the scores of the detected object (if there is an object detected, which one is it?)
#
# We know that the first 5 elements of the results ouputs are not the "scores", **i.e.** : *the 80 classes probabilities of what kind of object is detected*. That's why we'll start to store our outputs layers' values in different lists, the first one will stock all the **scores** from the fifth element to the last element (80th), then we'll collect the first 5 elements.
#
# For the 5th to 85th elements corresponding to *the objects scores*, we'll take the maximum value which will represent the **highest probability** about what's the object's class.
#
# #### Object detection function
#
# Based on what we've detailed above, we'll write an object detection function.

# %%
def object_detection(outputs, input_frame):
    """ This function will allow us to draw bounding boxes on detected objects in frames (images) """
    # first we'll collect the height, width and channel of the input frame (3 if the image is RGB, 1 if it's grayscale)
    height, width, channel = input_frame.shape
    
    # we'll create category lists to store the layers' output values 
    bounding_boxes = []
    class_objects = []
    confidence_probs = []
    
    # Knowing that there are 3 YOLO outputs' layers, we'll browsing them and their outputs using this :
    for result in outputs:        
        for values in result:
            
            scores = values[5:] # we know that the class probabilities are from the 5th values to the 85th
            indices_object = np.argmax(scores) # get the indice of the max score
            confidence_probability = scores[indices_object] # store the maximum value of the indice found
            
            # in order to have a proper detection, we'll eliminate the weakest probability detection by imposing a threshold
            if confidence_probability > confidenceThreshold:   
                
                # get the pixel values corresponding to the scaling of the bounding box coordinates to the initial frame
                box_detected = values[0:4] * np.array([width, height, width, height])                                 
                # get the top left corner coordinates by extracting values from box_detected and perform calculations
                x, y, w, h = box_detected
                # we're converting the coordinates to int because OpenCV doesn't allow floats for bounding boxes
                x = int(x - (w/2))
                y = int(y - (h/2))
                
                # adding the good detected boxe in the bounding boxes list created
                bounding_boxes.append([x,y,w,h])                
                # adding the detected objects indices in the class objects list 
                class_objects.append(indices_object)                
                # adding the max value of the object score (confidence) in the confidences_probs list
                confidence_probs.append(float(confidence_probability))    
    
    return bounding_boxes, class_objects, confidence_probs

# %% [markdown]
# #### Non-max suppresion function
#
# When we're doing object detection with YoloV3, the algorithm outputs several bounding boxes. In order to keep the best bounding box we'll need to perform a maximizimation technique called **non-max suppression**, this method will allow us to keep the bounding box with the highest probability and eliminate the others.

# %%
def nms_bbox(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold):
    """This function performs non-max suppression on all the bounding boxes detected and keeps the best one"""    
    #Using OpenCV DNN non-max supression to get the best bounding box of the detected object (retrieve the indices)
    indices_bbox = cv2.dnn.NMSBoxes(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold)   
    print('Number of objects detected : ', len(indices_bbox), '\n')
      
    return indices_bbox

# %% [markdown]
# #### Drawing box function
#
# Now, we have only one bounding box left (the best one) and we'll just need to draw the corresponding box.

# %%
def box_drawing(input_frame, indices, bounding_boxes, class_objects, confidence_probs, classNames, color=(0,255,255), thickness=2):
    """ Drawing the detected objects boxes """
    # once we have the indices, we'll extract the values of x,y,w,h of the best bounding boxes and stores it.
    for i in indices:
        i = i[0]
        final_box = bounding_boxes[i]
    # we'll retrieve the bounding boxes values (coordinates) now and use them to draw our boxes.
        x, y, w, h = final_box[0], final_box[1], final_box[2], final_box[3]
        x, y, w, h = int(x), int(y), int(w), int(h)        
        print('Bounding box coordinates in the frame : ', 'x : ', x,'|| y : ',y,'|| w : ',w,'|| h :',h , '\n')
    
        cv2.rectangle(input_frame, (x,y), (x+w,y+h),  (0, 255, 255), 2)
        cv2.putText(input_frame, f'{classNames[class_objects[i]].upper()} {int(confidence_probs[i]*100)}%',
                        (x, y-10), cv2.FONT_HERSHEY_DUPLEX, 0.6,  (0, 255, 255), 2)

# %% [markdown]
# ####  Blob function
#
# OpenCV uses blob techniques to extract features from an image and allows detection. In order to be able to do forward propagation on our images or videos, we'll need to convert our images to **OpenCV blob's format**.

# %%
def convert_to_blob(input_frame, network, height, width):
    """ This function allow us to convert a frame/image into blob format for OpenCV DNN"""    
    blob = cv2.dnn.blobFromImage(input_frame, 1/255, (height,width), [0,0,0], 1, crop=False)
    network.setInput(blob)
    # get the YOLO output layers numbers (names), these layers will be useful for the detection part
    # the layer's name : yolo_82, yolo_94, yolo_106
    yoloLayers = network.getLayerNames()
    outputLayers = [(yoloLayers[i[0]-1]) for i in network.getUnconnectedOutLayers()]
    # Doing forward propagation with OpenCV
    outputs = network.forward(outputLayers)
    
    return outputs

# %% [markdown]
# ### Test on webcam cameras

# %%
cap_camera = cv2.VideoCapture(0)

network = neural_net
height, width = 320,320

while cap_camera.isOpened():
    success, camera_frames = cap_camera.read()
    # if 'camera_frames' is read correctly 'success' is True
    if not success:
        print("Can't receive frame (stream end?). Exiting ...")
        break
        
    # using convert_to_blob function : 
    outputs = convert_to_blob(camera_frames, network, height, width)    
    # apply object detection on the video file
    bounding_boxes, class_objects, confidence_probs = object_detection(outputs, camera_frames)   
    # perform non-max suppression
    indices = nms_bbox(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold)
    # draw the boxes
    box_drawing(camera_frames, indices, bounding_boxes, class_objects, confidence_probs, classNames, color=(0,255,255), thickness=2)
        
    cv2.imshow('Object Detection with a camera', camera_frames)
    
    if cv2.waitKey(1) == ord('q'):
        break
        
cap_camera.release()
cv2.destroyAllWindows()
# Out:
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  52 || y :  54 || w :  557 || h : 430
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  48 || y :  56 || w :  568 || h : 427
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  55 || y :  58 || w :  556 || h : 426
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  93 || y :  53 || w :  522 || h : 425
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  71 || y :  55 || w :  533 || h : 424
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  57 || y :  57 || w :  552 || h : 427
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  82 || y :  54 || w :  530 || h : 434
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  87 || y :  56 || w :  526 || h : 432
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  88 || y :  56 || w :  529 || h : 427
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  70 || y :  47 || w :  555 || h : 432
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  56 || y :  48 || w :  572 || h : 434
#
# Bounding box coordinates in the frame :  x :  343 || y :  388 || w :  53 || h : 92
#
# Bounding box coordinates in the frame :  x :  309 || y :  387 || w :  44 || h : 94
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  48 || y :  51 || w :  573 || h : 420
#
# Bounding box coordinates in the frame :  x :  467 || y :  158 || w :  170 || h : 197
#
# Bounding box coordinates in the frame :  x :  343 || y :  389 || w :  52 || h : 90
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  57 || y :  51 || w :  565 || h : 422
#
# Bounding box coordinates in the frame :  x :  463 || y :  157 || w :  172 || h : 199
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  54 || y :  50 || w :  561 || h : 420
#
# Bounding box coordinates in the frame :  x :  466 || y :  157 || w :  167 || h : 195
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  52 || y :  52 || w :  567 || h : 424
#
# Bounding box coordinates in the frame :  x :  471 || y :  152 || w :  162 || h : 207
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  46 || y :  55 || w :  578 || h : 419
#
# Bounding box coordinates in the frame :  x :  468 || y :  151 || w :  165 || h : 205
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  41 || y :  49 || w :  588 || h : 427
#
# Bounding box coordinates in the frame :  x :  345 || y :  388 || w :  48 || h : 91
#
# Bounding box coordinates in the frame :  x :  476 || y :  152 || w :  153 || h : 204
#
# Bounding box coordinates in the frame :  x :  310 || y :  388 || w :  45 || h : 92
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  44 || y :  48 || w :  587 || h : 430
#
# Bounding box coordinates in the frame :  x :  344 || y :  388 || w :  49 || h : 92
#
# Bounding box coordinates in the frame :  x :  474 || y :  148 || w :  157 || h : 207
#
# Bounding box coordinates in the frame :  x :  310 || y :  388 || w :  44 || h : 92
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  45 || y :  51 || w :  585 || h : 423
#
# Bounding box coordinates in the frame :  x :  480 || y :  151 || w :  150 || h : 200
#
# Bounding box coordinates in the frame :  x :  345 || y :  389 || w :  50 || h : 91
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  48 || y :  49 || w :  576 || h : 424
#
# Bounding box coordinates in the frame :  x :  482 || y :  151 || w :  148 || h : 201
#
# Bounding box coordinates in the frame :  x :  345 || y :  388 || w :  48 || h : 91
#
# Bounding box coordinates in the frame :  x :  311 || y :  388 || w :  44 || h : 92
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  49 || y :  47 || w :  581 || h : 433
#
# Bounding box coordinates in the frame :  x :  480 || y :  151 || w :  151 || h : 202
#
# Bounding box coordinates in the frame :  x :  345 || y :  389 || w :  49 || h : 91
#
# Bounding box coordinates in the frame :  x :  310 || y :  389 || w :  44 || h : 92
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  45 || y :  49 || w :  586 || h : 428
#
# Bounding box coordinates in the frame :  x :  484 || y :  151 || w :  147 || h : 201
#
# Bounding box coordinates in the frame :  x :  342 || y :  388 || w :  49 || h : 92
#
# Bounding box coordinates in the frame :  x :  310 || y :  388 || w :  44 || h : 92
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  51 || y :  48 || w :  570 || h : 430
#
# Bounding box coordinates in the frame :  x :  492 || y :  150 || w :  137 || h : 199
#
# Bounding box coordinates in the frame :  x :  345 || y :  389 || w :  50 || h : 90
#
# Bounding box coordinates in the frame :  x :  310 || y :  389 || w :  44 || h : 91
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  50 || y :  49 || w :  571 || h : 428
#
# Bounding box coordinates in the frame :  x :  480 || y :  150 || w :  152 || h : 202
#
# Bounding box coordinates in the frame :  x :  344 || y :  389 || w :  51 || h : 90
#
# Bounding box coordinates in the frame :  x :  308 || y :  389 || w :  45 || h : 92
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  49 || y :  48 || w :  572 || h : 432
#
# Bounding box coordinates in the frame :  x :  486 || y :  152 || w :  149 || h : 197
#
# Bounding box coordinates in the frame :  x :  344 || y :  388 || w :  50 || h : 91
#
# Bounding box coordinates in the frame :  x :  309 || y :  388 || w :  44 || h : 92
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  47 || y :  47 || w :  578 || h : 430
#
# Bounding box coordinates in the frame :  x :  487 || y :  152 || w :  145 || h : 199
#
# Bounding box coordinates in the frame :  x :  346 || y :  389 || w :  50 || h : 90
#
# Bounding box coordinates in the frame :  x :  309 || y :  389 || w :  45 || h : 91
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  39 || y :  52 || w :  590 || h : 423
#
# Bounding box coordinates in the frame :  x :  488 || y :  152 || w :  144 || h : 198
#
# Bounding box coordinates in the frame :  x :  345 || y :  389 || w :  49 || h : 90
#
# Bounding box coordinates in the frame :  x :  310 || y :  388 || w :  44 || h : 92
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  50 || y :  50 || w :  569 || h : 429
#
# Bounding box coordinates in the frame :  x :  489 || y :  148 || w :  145 || h : 199
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  53 || y :  46 || w :  565 || h : 436
#
# Bounding box coordinates in the frame :  x :  488 || y :  137 || w :  149 || h : 192
#
# Bounding box coordinates in the frame :  x :  353 || y :  371 || w :  39 || h : 105
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  59 || y :  43 || w :  562 || h : 442
#
# Bounding box coordinates in the frame :  x :  495 || y :  135 || w :  146 || h : 193
#
# Bounding box coordinates in the frame :  x :  350 || y :  370 || w :  40 || h : 106
#
# Bounding box coordinates in the frame :  x :  311 || y :  373 || w :  37 || h : 106
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  50 || y :  41 || w :  576 || h : 443
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  49 || y :  36 || w :  584 || h : 447
#
# Bounding box coordinates in the frame :  x :  374 || y :  367 || w :  35 || h : 106
#
# Bounding box coordinates in the frame :  x :  343 || y :  366 || w :  41 || h : 108
#
# Bounding box coordinates in the frame :  x :  315 || y :  368 || w :  39 || h : 109
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  62 || y :  34 || w :  579 || h : 453
#
# Bounding box coordinates in the frame :  x :  373 || y :  366 || w :  36 || h : 108
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  61 || y :  33 || w :  580 || h : 450
#
# Bounding box coordinates in the frame :  x :  374 || y :  366 || w :  35 || h : 109
#
# Bounding box coordinates in the frame :  x :  314 || y :  368 || w :  40 || h : 110
#
# Bounding box coordinates in the frame :  x :  345 || y :  365 || w :  39 || h : 113
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  33 || w :  575 || h : 452
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  61 || y :  35 || w :  574 || h : 446
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  75 || y :  47 || w :  550 || h : 420
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  63 || y :  34 || w :  569 || h : 449
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  83 || y :  44 || w :  526 || h : 446
#
# Bounding box coordinates in the frame :  x :  243 || y :  152 || w :  131 || h : 194
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  210 || y :  128 || w :  128 || h : 193
#
# Bounding box coordinates in the frame :  x :  64 || y :  59 || w :  558 || h : 417
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  187 || y :  143 || w :  130 || h : 179
#
# Bounding box coordinates in the frame :  x :  102 || y :  48 || w :  513 || h : 420
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  177 || y :  145 || w :  126 || h : 174
#
# Bounding box coordinates in the frame :  x :  80 || y :  44 || w :  521 || h : 420
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  71 || y :  48 || w :  539 || h : 413
#
# Bounding box coordinates in the frame :  x :  172 || y :  147 || w :  122 || h : 169
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  176 || y :  145 || w :  128 || h : 163
#
# Bounding box coordinates in the frame :  x :  68 || y :  43 || w :  544 || h : 425
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  64 || y :  34 || w :  550 || h : 442
#
# Bounding box coordinates in the frame :  x :  181 || y :  138 || w :  102 || h : 174
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  162 || y :  142 || w :  110 || h : 157
#
# Bounding box coordinates in the frame :  x :  72 || y :  39 || w :  545 || h : 432
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  45 || y :  36 || w :  596 || h : 437
#
# Bounding box coordinates in the frame :  x :  138 || y :  140 || w :  92 || h : 164
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  35 || y :  44 || w :  599 || h : 424
#
# Bounding box coordinates in the frame :  x :  126 || y :  129 || w :  78 || h : 154
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  28 || y :  44 || w :  612 || h : 420
#
# Bounding box coordinates in the frame :  x :  123 || y :  114 || w :  88 || h : 186
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  32 || y :  42 || w :  608 || h : 428
#
# Bounding box coordinates in the frame :  x :  122 || y :  106 || w :  90 || h : 188
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  21 || y :  45 || w :  621 || h : 420
#
# Bounding box coordinates in the frame :  x :  120 || y :  100 || w :  88 || h : 172
#
# Bounding box coordinates in the frame :  x :  324 || y :  369 || w :  40 || h : 109
#
# Bounding box coordinates in the frame :  x :  379 || y :  367 || w :  42 || h : 107
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  19 || y :  43 || w :  622 || h : 419
#
# Bounding box coordinates in the frame :  x :  119 || y :  99 || w :  93 || h : 171
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  20 || y :  41 || w :  626 || h : 424
#
# Bounding box coordinates in the frame :  x :  121 || y :  95 || w :  91 || h : 182
#
# Bounding box coordinates in the frame :  x :  373 || y :  357 || w :  52 || h : 114
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  28 || y :  45 || w :  612 || h : 415
#
# Bounding box coordinates in the frame :  x :  132 || y :  85 || w :  85 || h : 187
#
# Bounding box coordinates in the frame :  x :  375 || y :  354 || w :  49 || h : 117
#
# Bounding box coordinates in the frame :  x :  337 || y :  356 || w :  47 || h : 115
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  31 || y :  44 || w :  608 || h : 418
#
# Bounding box coordinates in the frame :  x :  134 || y :  79 || w :  87 || h : 188
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  32 || y :  43 || w :  606 || h : 419
#
# Bounding box coordinates in the frame :  x :  132 || y :  81 || w :  86 || h : 188
#
# Bounding box coordinates in the frame :  x :  372 || y :  352 || w :  53 || h : 120
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  29 || y :  48 || w :  610 || h : 410
#
# Bounding box coordinates in the frame :  x :  131 || y :  85 || w :  88 || h : 181
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  30 || y :  45 || w :  608 || h : 417
#
# Bounding box coordinates in the frame :  x :  131 || y :  85 || w :  86 || h : 180
#
# Bounding box coordinates in the frame :  x :  374 || y :  353 || w :  51 || h : 119
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  30 || y :  45 || w :  612 || h : 418
#
# Bounding box coordinates in the frame :  x :  132 || y :  81 || w :  85 || h : 185
#
# Bounding box coordinates in the frame :  x :  373 || y :  353 || w :  53 || h : 118
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  30 || y :  44 || w :  606 || h : 418
#
# Bounding box coordinates in the frame :  x :  132 || y :  82 || w :  87 || h : 188
#
# Bounding box coordinates in the frame :  x :  373 || y :  352 || w :  53 || h : 119
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  29 || y :  40 || w :  609 || h : 424
#
# Bounding box coordinates in the frame :  x :  133 || y :  84 || w :  84 || h : 180
#
# Bounding box coordinates in the frame :  x :  375 || y :  353 || w :  49 || h : 117
#
# Bounding box coordinates in the frame :  x :  340 || y :  355 || w :  40 || h : 98
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  34 || y :  47 || w :  598 || h : 415
#
# Bounding box coordinates in the frame :  x :  133 || y :  81 || w :  87 || h : 188
#
# Bounding box coordinates in the frame :  x :  374 || y :  353 || w :  53 || h : 119
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  32 || y :  46 || w :  608 || h : 415
#
# Bounding box coordinates in the frame :  x :  135 || y :  82 || w :  85 || h : 186
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  31 || y :  51 || w :  609 || h : 408
#
# Bounding box coordinates in the frame :  x :  137 || y :  87 || w :  89 || h : 177
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  36 || y :  55 || w :  598 || h : 404
#
# Bounding box coordinates in the frame :  x :  141 || y :  86 || w :  87 || h : 177
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  45 || y :  67 || w :  587 || h : 390
#
# Bounding box coordinates in the frame :  x :  148 || y :  88 || w :  79 || h : 174
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  49 || y :  62 || w :  584 || h : 396
#
# Bounding box coordinates in the frame :  x :  156 || y :  89 || w :  78 || h : 143
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  53 || y :  60 || w :  589 || h : 402
#
# Bounding box coordinates in the frame :  x :  165 || y :  84 || w :  76 || h : 151
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  62 || y :  67 || w :  579 || h : 399
#
# Bounding box coordinates in the frame :  x :  168 || y :  89 || w :  76 || h : 146
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  60 || y :  75 || w :  582 || h : 392
#
# Bounding box coordinates in the frame :  x :  172 || y :  95 || w :  80 || h : 156
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  53 || y :  81 || w :  592 || h : 380
#
# Bounding box coordinates in the frame :  x :  183 || y :  93 || w :  66 || h : 125
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  45 || y :  96 || w :  597 || h : 366
#
# Bounding box coordinates in the frame :  x :  185 || y :  101 || w :  67 || h : 111
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  86 || y :  82 || w :  539 || h : 390
#
# Bounding box coordinates in the frame :  x :  194 || y :  116 || w :  70 || h : 124
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  81 || y :  79 || w :  550 || h : 398
#
# Bounding box coordinates in the frame :  x :  203 || y :  136 || w :  83 || h : 142
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  63 || y :  82 || w :  572 || h : 394
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  100 || y :  90 || w :  528 || h : 380
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  280 || y :  243 || w :  71 || h : 110
#
# Bounding box coordinates in the frame :  x :  178 || y :  119 || w :  442 || h : 355
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  176 || y :  116 || w :  441 || h : 361
#
# Bounding box coordinates in the frame :  x :  290 || y :  264 || w :  67 || h : 121
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  58 || y :  109 || w :  577 || h : 377
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  51 || y :  102 || w :  585 || h : 384
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  32 || y :  80 || w :  612 || h : 394
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  28 || y :  75 || w :  613 || h : 399
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  31 || y :  59 || w :  600 || h : 422
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  33 || y :  53 || w :  599 || h : 430
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  39 || y :  56 || w :  593 || h : 425
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  29 || y :  55 || w :  606 || h : 426
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  29 || y :  50 || w :  613 || h : 433
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  40 || y :  52 || w :  594 || h : 426
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -16 || y :  38 || w :  654 || h : 447
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -19 || y :  48 || w :  654 || h : 426
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -16 || y :  48 || w :  646 || h : 426
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -15 || y :  51 || w :  646 || h : 418
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -5 || y :  54 || w :  630 || h : 413
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -10 || y :  55 || w :  638 || h : 408
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -11 || y :  55 || w :  638 || h : 410
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -4 || y :  51 || w :  623 || h : 414
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -6 || y :  39 || w :  627 || h : 447
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -3 || y :  32 || w :  624 || h : 450
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -4 || y :  29 || w :  629 || h : 458
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  64 || w :  543 || h : 418
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  31 || y :  120 || w :  603 || h : 364
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  71 || y :  21 || w :  559 || h : 488
#
# Bounding box coordinates in the frame :  x :  273 || y :  170 || w :  192 || h : 177
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  81 || y :  64 || w :  548 || h : 402
#
# Bounding box coordinates in the frame :  x :  298 || y :  201 || w :  217 || h : 200
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  46 || w :  561 || h : 432
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  74 || y :  54 || w :  545 || h : 422
#
# Bounding box coordinates in the frame :  x :  443 || y :  357 || w :  180 || h : 115
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  83 || y :  57 || w :  530 || h : 417
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  75 || y :  56 || w :  539 || h : 415
#
# Bounding box coordinates in the frame :  x :  371 || y :  361 || w :  36 || h : 110
#
# Bounding box coordinates in the frame :  x :  318 || y :  364 || w :  26 || h : 94
#
# Bounding box coordinates in the frame :  x :  -6 || y :  149 || w :  186 || h : 327
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  51 || w :  551 || h : 425
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  69 || y :  52 || w :  545 || h : 425
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  60 || y :  54 || w :  555 || h : 420
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  70 || y :  48 || w :  532 || h : 424
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  68 || y :  45 || w :  540 || h : 434
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  67 || y :  49 || w :  539 || h : 428
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  60 || y :  54 || w :  567 || h : 423
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  51 || y :  56 || w :  583 || h : 421
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  66 || y :  57 || w :  547 || h : 423
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  65 || w :  549 || h : 413
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  51 || y :  52 || w :  573 || h : 429
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  56 || y :  52 || w :  560 || h : 432
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  48 || w :  557 || h : 441
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  69 || y :  60 || w :  539 || h : 425
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  70 || y :  53 || w :  540 || h : 431
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  63 || y :  61 || w :  546 || h : 421
#
# Bounding box coordinates in the frame :  x :  224 || y :  212 || w :  230 || h : 196
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  61 || y :  60 || w :  550 || h : 425
#
# Bounding box coordinates in the frame :  x :  222 || y :  213 || w :  231 || h : 193
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  46 || y :  56 || w :  576 || h : 422
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  42 || w :  560 || h : 448
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  56 || y :  42 || w :  563 || h : 440
#
# Bounding box coordinates in the frame :  x :  133 || y :  150 || w :  212 || h : 221
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  57 || y :  55 || w :  557 || h : 416
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  55 || w :  542 || h : 416
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  -2 || y :  61 || w :  612 || h : 401
#
# Bounding box coordinates in the frame :  x :  113 || y :  133 || w :  209 || h : 182
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  70 || y :  56 || w :  532 || h : 413
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -5 || y :  57 || w :  622 || h : 412
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  73 || y :  46 || w :  530 || h : 430
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  80 || y :  50 || w :  521 || h : 421
#
# Bounding box coordinates in the frame :  x :  119 || y :  201 || w :  214 || h : 131
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  -19 || y :  47 || w :  643 || h : 431
#
# Bounding box coordinates in the frame :  x :  118 || y :  202 || w :  223 || h : 132
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  -15 || y :  42 || w :  636 || h : 444
#
# Bounding box coordinates in the frame :  x :  117 || y :  194 || w :  224 || h : 149
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  -10 || y :  44 || w :  627 || h : 438
#
# Bounding box coordinates in the frame :  x :  115 || y :  192 || w :  226 || h : 151
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  -18 || y :  46 || w :  644 || h : 438
#
# Bounding box coordinates in the frame :  x :  114 || y :  199 || w :  229 || h : 138
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  -6 || y :  44 || w :  621 || h : 437
#
# Bounding box coordinates in the frame :  x :  116 || y :  199 || w :  220 || h : 142
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  -13 || y :  42 || w :  631 || h : 441
#
# Bounding box coordinates in the frame :  x :  114 || y :  198 || w :  228 || h : 138
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  -6 || y :  42 || w :  620 || h : 443
#
# Bounding box coordinates in the frame :  x :  115 || y :  200 || w :  226 || h : 141
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -18 || y :  42 || w :  644 || h : 436
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  -27 || y :  51 || w :  660 || h : 426
#
# Bounding box coordinates in the frame :  x :  111 || y :  191 || w :  225 || h : 144
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  68 || y :  53 || w :  554 || h : 412
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  63 || y :  51 || w :  558 || h : 412
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  63 || y :  55 || w :  560 || h : 413
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  66 || y :  48 || w :  555 || h : 420
#
# Bounding box coordinates in the frame :  x :  113 || y :  188 || w :  220 || h : 157
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  72 || y :  52 || w :  548 || h : 413
#
# Bounding box coordinates in the frame :  x :  119 || y :  190 || w :  215 || h : 154
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  74 || y :  57 || w :  538 || h : 412
#
# Bounding box coordinates in the frame :  x :  120 || y :  194 || w :  214 || h : 138
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  72 || y :  56 || w :  542 || h : 414
#
# Bounding box coordinates in the frame :  x :  118 || y :  198 || w :  219 || h : 133
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  79 || y :  56 || w :  539 || h : 416
#
# Bounding box coordinates in the frame :  x :  124 || y :  198 || w :  210 || h : 133
#
# Bounding box coordinates in the frame :  x :  4 || y :  219 || w :  154 || h : 259
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  72 || y :  54 || w :  549 || h : 415
#
# Bounding box coordinates in the frame :  x :  123 || y :  200 || w :  216 || h : 131
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  70 || y :  62 || w :  546 || h : 407
#
# Bounding box coordinates in the frame :  x :  121 || y :  199 || w :  213 || h : 128
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  71 || y :  58 || w :  541 || h : 411
#
# Bounding box coordinates in the frame :  x :  120 || y :  196 || w :  218 || h : 132
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  65 || y :  62 || w :  549 || h : 402
#
# Bounding box coordinates in the frame :  x :  119 || y :  203 || w :  219 || h : 126
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  71 || y :  53 || w :  540 || h : 418
#
# Bounding box coordinates in the frame :  x :  121 || y :  197 || w :  215 || h : 128
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  68 || y :  60 || w :  547 || h : 407
#
# Bounding box coordinates in the frame :  x :  120 || y :  196 || w :  216 || h : 129
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  69 || y :  63 || w :  545 || h : 410
#
# Bounding box coordinates in the frame :  x :  127 || y :  201 || w :  211 || h : 125
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  70 || y :  60 || w :  536 || h : 412
#
# Bounding box coordinates in the frame :  x :  126 || y :  196 || w :  210 || h : 131
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  81 || y :  62 || w :  539 || h : 409
#
# Bounding box coordinates in the frame :  x :  127 || y :  195 || w :  210 || h : 130
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  73 || y :  52 || w :  550 || h : 422
#
# Bounding box coordinates in the frame :  x :  123 || y :  197 || w :  218 || h : 128
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  82 || y :  55 || w :  531 || h : 419
#
# Bounding box coordinates in the frame :  x :  124 || y :  203 || w :  213 || h : 121
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  85 || y :  55 || w :  534 || h : 416
#
# Bounding box coordinates in the frame :  x :  121 || y :  205 || w :  215 || h : 121
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  77 || y :  59 || w :  542 || h : 415
#
# Bounding box coordinates in the frame :  x :  121 || y :  204 || w :  216 || h : 117
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  76 || y :  54 || w :  541 || h : 420
#
# Bounding box coordinates in the frame :  x :  125 || y :  202 || w :  217 || h : 122
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  73 || y :  61 || w :  545 || h : 415
#
# Bounding box coordinates in the frame :  x :  125 || y :  202 || w :  215 || h : 119
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  83 || y :  64 || w :  537 || h : 409
#
# Bounding box coordinates in the frame :  x :  122 || y :  204 || w :  218 || h : 117
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  81 || y :  60 || w :  544 || h : 415
#
# Bounding box coordinates in the frame :  x :  125 || y :  203 || w :  215 || h : 122
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  88 || y :  56 || w :  524 || h : 420
#
# Bounding box coordinates in the frame :  x :  127 || y :  206 || w :  219 || h : 116
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  94 || y :  61 || w :  509 || h : 412
#
# Bounding box coordinates in the frame :  x :  143 || y :  231 || w :  206 || h : 96
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  81 || y :  64 || w :  527 || h : 402
#
# Bounding box coordinates in the frame :  x :  163 || y :  247 || w :  195 || h : 78
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  81 || y :  72 || w :  524 || h : 391
#
# Bounding box coordinates in the frame :  x :  177 || y :  246 || w :  184 || h : 76
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  66 || y :  63 || w :  551 || h : 411
#
# Bounding box coordinates in the frame :  x :  178 || y :  269 || w :  191 || h : 118
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  88 || y :  65 || w :  514 || h : 416
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  84 || y :  70 || w :  515 || h : 401
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  72 || y :  66 || w :  527 || h : 405
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  79 || y :  59 || w :  518 || h : 410
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  73 || y :  65 || w :  524 || h : 411
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  80 || y :  61 || w :  521 || h : 412
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  79 || y :  60 || w :  530 || h : 412
#
# Bounding box coordinates in the frame :  x :  248 || y :  235 || w :  241 || h : 151
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  67 || y :  52 || w :  545 || h : 430
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  68 || y :  45 || w :  544 || h : 440
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  82 || y :  43 || w :  528 || h : 446
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  75 || y :  53 || w :  530 || h : 430
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  78 || y :  50 || w :  538 || h : 429
#
# Bounding box coordinates in the frame :  x :  299 || y :  239 || w :  190 || h : 178
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  67 || y :  50 || w :  549 || h : 432
#
# Bounding box coordinates in the frame :  x :  303 || y :  236 || w :  187 || h : 175
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  66 || y :  55 || w :  551 || h : 425
#
# Bounding box coordinates in the frame :  x :  302 || y :  236 || w :  197 || h : 174
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  79 || y :  49 || w :  533 || h : 433
#
# Bounding box coordinates in the frame :  x :  303 || y :  237 || w :  189 || h : 180
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  70 || y :  49 || w :  546 || h : 431
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  45 || w :  556 || h : 438
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  68 || y :  56 || w :  558 || h : 423
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  69 || y :  53 || w :  561 || h : 428
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  51 || w :  562 || h : 427
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  57 || y :  50 || w :  570 || h : 423
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  53 || y :  52 || w :  575 || h : 431
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  55 || y :  44 || w :  579 || h : 440
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  46 || w :  573 || h : 439
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  48 || y :  43 || w :  581 || h : 442
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  54 || y :  44 || w :  577 || h : 445
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  47 || w :  562 || h : 438
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  85 || y :  54 || w :  527 || h : 430
#
# Bounding box coordinates in the frame :  x :  -5 || y :  216 || w :  198 || h : 263
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  89 || y :  68 || w :  513 || h : 399
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  80 || y :  66 || w :  510 || h : 411
#
# Bounding box coordinates in the frame :  x :  251 || y :  181 || w :  154 || h : 191
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  80 || y :  56 || w :  509 || h : 428
#
# Bounding box coordinates in the frame :  x :  213 || y :  185 || w :  182 || h : 160
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  69 || y :  54 || w :  540 || h : 424
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  67 || y :  51 || w :  535 || h : 426
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  70 || y :  51 || w :  529 || h : 424
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  66 || y :  50 || w :  539 || h : 422
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  66 || y :  47 || w :  538 || h : 430
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  49 || w :  537 || h : 426
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  44 || w :  540 || h : 435
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  62 || y :  36 || w :  548 || h : 448
#
# Bounding box coordinates in the frame :  x :  232 || y :  179 || w :  193 || h : 139
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  59 || y :  36 || w :  547 || h : 445
#
# Bounding box coordinates in the frame :  x :  228 || y :  179 || w :  196 || h : 143
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  61 || y :  37 || w :  547 || h : 448
#
# Bounding box coordinates in the frame :  x :  235 || y :  186 || w :  185 || h : 128
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  64 || y :  36 || w :  542 || h : 448
#
# Bounding box coordinates in the frame :  x :  227 || y :  186 || w :  198 || h : 130
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  69 || y :  30 || w :  530 || h : 456
#
# Bounding box coordinates in the frame :  x :  238 || y :  180 || w :  192 || h : 141
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  63 || y :  43 || w :  547 || h : 441
#
# Bounding box coordinates in the frame :  x :  255 || y :  170 || w :  169 || h : 154
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  63 || y :  49 || w :  545 || h : 434
#
# Bounding box coordinates in the frame :  x :  258 || y :  170 || w :  171 || h : 161
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  58 || y :  50 || w :  552 || h : 435
#
# Bounding box coordinates in the frame :  x :  259 || y :  173 || w :  164 || h : 155
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  61 || y :  50 || w :  542 || h : 433
#
# Bounding box coordinates in the frame :  x :  259 || y :  172 || w :  162 || h : 153
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  64 || y :  47 || w :  537 || h : 440
#
# Bounding box coordinates in the frame :  x :  260 || y :  170 || w :  160 || h : 158
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  49 || w :  542 || h : 434
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  63 || y :  46 || w :  546 || h : 438
#
# Bounding box coordinates in the frame :  x :  263 || y :  172 || w :  157 || h : 153
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  56 || y :  45 || w :  558 || h : 438
#
# Bounding box coordinates in the frame :  x :  264 || y :  172 || w :  156 || h : 154
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  61 || y :  54 || w :  548 || h : 427
#
# Bounding box coordinates in the frame :  x :  255 || y :  169 || w :  168 || h : 162
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  63 || y :  50 || w :  545 || h : 432
#
# Bounding box coordinates in the frame :  x :  256 || y :  170 || w :  167 || h : 159
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  55 || y :  50 || w :  559 || h : 432
#
# Bounding box coordinates in the frame :  x :  266 || y :  174 || w :  156 || h : 151
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  56 || y :  39 || w :  555 || h : 447
#
# Bounding box coordinates in the frame :  x :  258 || y :  172 || w :  170 || h : 150
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  70 || y :  33 || w :  525 || h : 458
#
# Bounding box coordinates in the frame :  x :  243 || y :  179 || w :  187 || h : 138
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  65 || y :  37 || w :  533 || h : 447
#
# Bounding box coordinates in the frame :  x :  238 || y :  185 || w :  184 || h : 122
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  65 || y :  40 || w :  536 || h : 439
#
# Bounding box coordinates in the frame :  x :  228 || y :  181 || w :  199 || h : 132
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  81 || y :  42 || w :  510 || h : 446
#
# Bounding box coordinates in the frame :  x :  260 || y :  165 || w :  162 || h : 121
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  78 || y :  43 || w :  521 || h : 449
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  76 || y :  45 || w :  525 || h : 446
#
# Bounding box coordinates in the frame :  x :  262 || y :  170 || w :  169 || h : 114
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  78 || y :  41 || w :  523 || h : 449
#
# Bounding box coordinates in the frame :  x :  266 || y :  167 || w :  161 || h : 117
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  74 || y :  46 || w :  532 || h : 446
#
# Bounding box coordinates in the frame :  x :  269 || y :  168 || w :  164 || h : 115
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  82 || y :  46 || w :  520 || h : 444
#
# Bounding box coordinates in the frame :  x :  263 || y :  172 || w :  168 || h : 111
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  81 || y :  42 || w :  521 || h : 449
#
# Bounding box coordinates in the frame :  x :  272 || y :  172 || w :  161 || h : 113
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  74 || y :  43 || w :  528 || h : 448
#
# Bounding box coordinates in the frame :  x :  288 || y :  169 || w :  140 || h : 129
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  69 || y :  42 || w :  540 || h : 448
#
# Bounding box coordinates in the frame :  x :  267 || y :  172 || w :  164 || h : 114
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  75 || y :  37 || w :  533 || h : 456
#
# Bounding box coordinates in the frame :  x :  287 || y :  169 || w :  141 || h : 129
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  76 || y :  51 || w :  522 || h : 443
#
# Bounding box coordinates in the frame :  x :  267 || y :  176 || w :  150 || h : 143
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  83 || y :  49 || w :  505 || h : 447
#
# Bounding box coordinates in the frame :  x :  253 || y :  174 || w :  162 || h : 149
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  80 || y :  48 || w :  513 || h : 451
#
# Bounding box coordinates in the frame :  x :  254 || y :  175 || w :  162 || h : 148
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  80 || y :  51 || w :  514 || h : 446
#
# Bounding box coordinates in the frame :  x :  251 || y :  177 || w :  166 || h : 145
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  83 || y :  49 || w :  509 || h : 449
#
# Bounding box coordinates in the frame :  x :  252 || y :  176 || w :  168 || h : 149
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  76 || y :  54 || w :  522 || h : 445
#
# Bounding box coordinates in the frame :  x :  256 || y :  177 || w :  162 || h : 148
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  84 || y :  44 || w :  511 || h : 461
#
# Bounding box coordinates in the frame :  x :  250 || y :  178 || w :  173 || h : 146
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  79 || y :  43 || w :  515 || h : 463
#
# Bounding box coordinates in the frame :  x :  251 || y :  183 || w :  172 || h : 142
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  85 || y :  47 || w :  512 || h : 459
#
# Bounding box coordinates in the frame :  x :  248 || y :  184 || w :  203 || h : 162
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  90 || y :  49 || w :  506 || h : 457
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  88 || y :  41 || w :  505 || h : 469
#
# Bounding box coordinates in the frame :  x :  247 || y :  186 || w :  204 || h : 163
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  87 || y :  39 || w :  505 || h : 468
#
# Bounding box coordinates in the frame :  x :  245 || y :  187 || w :  198 || h : 161
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  91 || y :  48 || w :  502 || h : 454
#
# Bounding box coordinates in the frame :  x :  244 || y :  189 || w :  198 || h : 160
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  94 || y :  46 || w :  494 || h : 458
#
# Bounding box coordinates in the frame :  x :  241 || y :  192 || w :  181 || h : 148
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  83 || y :  65 || w :  519 || h : 404
#
# Bounding box coordinates in the frame :  x :  260 || y :  232 || w :  224 || h : 160
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  73 || y :  54 || w :  533 || h : 423
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  96 || y :  51 || w :  513 || h : 446
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  102 || y :  53 || w :  505 || h : 438
#
# Bounding box coordinates in the frame :  x :  58 || y :  346 || w :  233 || h : 133
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  140 || y :  90 || w :  458 || h : 363
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  106 || y :  73 || w :  509 || h : 408
#
# Bounding box coordinates in the frame :  x :  83 || y :  372 || w :  192 || h : 96
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  112 || y :  73 || w :  504 || h : 408
#
# Bounding box coordinates in the frame :  x :  89 || y :  385 || w :  235 || h : 81
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  89 || y :  73 || w :  537 || h : 403
#
# Bounding box coordinates in the frame :  x :  86 || y :  378 || w :  241 || h : 95
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  53 || y :  70 || w :  574 || h : 403
#
# Bounding box coordinates in the frame :  x :  114 || y :  292 || w :  115 || h : 160
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  75 || w :  569 || h : 396
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  78 || y :  68 || w :  551 || h : 410
#
# Bounding box coordinates in the frame :  x :  73 || y :  416 || w :  187 || h : 50
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  71 || y :  78 || w :  553 || h : 400
#
# Bounding box coordinates in the frame :  x :  111 || y :  412 || w :  124 || h : 55
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  76 || y :  77 || w :  545 || h : 397
#
# Bounding box coordinates in the frame :  x :  38 || y :  417 || w :  196 || h : 52
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  75 || y :  72 || w :  546 || h : 403
#
# Bounding box coordinates in the frame :  x :  6 || y :  393 || w :  214 || h : 67
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  20 || y :  50 || w :  559 || h : 432
#
# Bounding box coordinates in the frame :  x :  1 || y :  350 || w :  145 || h : 92
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -1 || y :  55 || w :  496 || h : 418
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  21 || y :  63 || w :  437 || h : 397
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  33 || y :  54 || w :  413 || h : 409
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  9 || y :  44 || w :  545 || h : 437
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -5 || y :  44 || w :  616 || h : 436
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -7 || y :  44 || w :  616 || h : 431
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -8 || y :  45 || w :  610 || h : 428
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -5 || y :  44 || w :  602 || h : 428
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  1 || y :  40 || w :  590 || h : 434
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -1 || y :  39 || w :  594 || h : 434
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  0 || y :  42 || w :  595 || h : 430
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -8 || y :  44 || w :  609 || h : 427
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -9 || y :  39 || w :  610 || h : 436
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -9 || y :  40 || w :  611 || h : 433
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -11 || y :  40 || w :  604 || h : 433
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -4 || y :  36 || w :  601 || h : 441
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -3 || y :  36 || w :  603 || h : 442
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  1 || y :  28 || w :  607 || h : 459
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -1 || y :  31 || w :  621 || h : 450
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  0 || y :  27 || w :  624 || h : 461
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  43 || y :  45 || w :  583 || h : 439
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  44 || y :  59 || w :  571 || h : 425
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  52 || y :  64 || w :  563 || h : 408
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  52 || w :  560 || h : 428
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  53 || y :  49 || w :  589 || h : 434
