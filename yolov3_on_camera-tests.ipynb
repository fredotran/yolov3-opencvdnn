# %% [markdown]
# # Using YOLOv3 and OpenCV 4 to detect objects
#
# I wanted to try to use OpenCV and YoloV3 in order to detect basics objects, this is what this notebook will be about.
#
# *Thank you Joseph Redmon and Ali Farhadi for their incredible work on YOLO object detector* : **YOLOv3: An Incremental Improvement**, *Redmon, Joseph and Farhadi, Ali* ; arXiv, 2018.
#
# This paper was my main inspiration for this notebook.

# %%
# import useful libraries
import os
import numpy as np
import cv2
print('OpenCV version : ', cv2. __version__)
print(cv2.cuda.getCudaEnabledDeviceCount())
# Out:
# OpenCV version :  4.5.1
# 1

# %% [markdown]
# ### Load YoloV3 models with pre-trained weights

# %%
# function to load our classes names
def read_classes(file):
    """ Read the classes files and extract the classes' names in it""" 
    classNames = []    
    with open(file, 'rt') as f:
        classNames = f.read().rstrip('\n').split('\n')
   
    return classNames

# %%
# read the file with the classes names
img_file = './data/coco.names'
classNames = read_classes(img_file)
#classNames

# %% [markdown]
# ### YoloV3 weights and cfg files
#
# In this part we'll upload YoloV3 Weights and cfg files in order to input them into cv2.dnn.readNetFromDarknet() and build our forward propagation with OpenCV. The weights and configs can be downloaded at : https://pjreddie.com/darknet/yolo/

# %%
# load the model config and weights
modelConfig_path = './cfg/yolov3.cfg'
modelWeights_path = './models/yolov3-320.weights'

# read the model cfg and weights with the cv2 DNN module
neural_net = cv2.dnn.readNetFromDarknet(modelConfig_path, modelWeights_path)
# set the preferable Backend to GPU
neural_net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
neural_net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

# confidence and non-max suppression threshold for this YoloV3 version
confidenceThreshold = 0.3
nmsThreshold = 0.2

# %% [markdown]
# ## Function creation for object detection
#
# In this part, we'll define the object detection function which allows us to get **the output of the three YOLO layers (82,94,106)** and select **the best bounding box** to put on the detected object, the layers' outputs are in the format :
# - The confidence probability (if there is an object or not in the frame)
# - (x,y) coordinates of the center of the object
# - (height, width) of the frame
# - All the scores of the detected object (if there is an object detected, which one is it?)
#
# We know that the first 5 elements of the results ouputs are not the "scores", **i.e.** : *the 80 classes probabilities of what kind of object is detected*. That's why we'll start to store our outputs layers' values in different lists, the first one will stock all the **scores** from the fifth element to the last element (85th), then we'll collect the first 5 elements.
#
# For the 5th to 85th elements corresponding to *the objects scores*, we'll take the maximum value which will represent the **highest probability** about what's the object's class.
#
# #### Object detection function
#
# Based on what we've detailed above, we'll write an object detection function.

# %%
def object_detection(outputs, input_frame):
    """ This function will allow us to draw bounding boxes on detected objects in frames (images) """
    # first we'll collect the height, width and channel of the input frame (3 if the image is RGB, 1 if it's grayscale)
    height, width, channel = input_frame.shape
    
    # we'll create category lists to store the layers' output values 
    bounding_boxes = []
    class_objects = []
    confidence_probs = []
    
    # Knowing that there are 3 YOLO outputs' layers, we'll browsing them and their outputs using this :
    for result in outputs:        
        for values in result:
            
            scores = values[5:] # we know that the class probabilities are from the 5th values to the 85th
            indices_object = np.argmax(scores) # get the indice of the max score
            confidence_probability = scores[indices_object] # store the maximum value of the indice found
            
            # in order to have a proper detection, we'll eliminate the weakest probability detection by imposing a threshold
            if confidence_probability > confidenceThreshold:   
                
                # get the pixel values corresponding to the scaling of the bounding box coordinates to the initial frame
                box_detected = values[0:4] * np.array([width, height, width, height])                                 
                # get the top left corner coordinates by extracting values from box_detected and perform calculations
                x, y, w, h = box_detected
                # we're converting the coordinates to int because OpenCV doesn't allow floats for bounding boxes
                x = int(x - (w/2))
                y = int(y - (h/2))
                
                # adding the good detected boxe in the bounding boxes list created
                bounding_boxes.append([x,y,w,h])                
                # adding the detected objects indices in the class objects list 
                class_objects.append(indices_object)                
                # adding the max value of the object score (confidence) in the confidences_probs list
                confidence_probs.append(float(confidence_probability))    
    
    return bounding_boxes, class_objects, confidence_probs

# %% [markdown]
# #### Non-max suppresion function
#
# When we're doing object detection with YoloV3, the algorithm outputs several bounding boxes. In order to keep the best bounding box we'll need to perform a maximizimation technique called **non-max suppression**, this method will allow us to keep the bounding box with the highest probability and eliminate the others.

# %%
def nms_bbox(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold):
    """This function performs non-max suppression on all the bounding boxes detected and keeps the best one"""    
    #Using OpenCV DNN non-max supression to get the best bounding box of the detected object (retrieve the indices)
    indices_bbox = cv2.dnn.NMSBoxes(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold)   
    print('Number of objects detected : ', len(indices_bbox), '\n')
      
    return indices_bbox

# %% [markdown]
# #### Drawing box function
#
# Now, we have only one bounding box left (the best one) and we'll just need to draw the corresponding box.

# %%
def box_drawing(input_frame, indices, bounding_boxes, class_objects, confidence_probs, classNames, color=(0,255,255), thickness=2):
    """ Drawing the detected objects boxes """
    # once we have the indices, we'll extract the values of x,y,w,h of the best bounding boxes and stores it.
    for i in indices:
        i = i[0]
        final_box = bounding_boxes[i]
    # we'll retrieve the bounding boxes values (coordinates) now and use them to draw our boxes.
        x, y, w, h = final_box[0], final_box[1], final_box[2], final_box[3]
        x, y, w, h = int(x), int(y), int(w), int(h)        
        print('Bounding box coordinates in the frame : ', 'x : ', x,'|| y : ',y,'|| w : ',w,'|| h :',h , '\n')
    
        cv2.rectangle(input_frame, (x,y), (x+w,y+h),  color, 2)
        cv2.putText(input_frame, f'{classNames[class_objects[i]].upper()} {int(confidence_probs[i]*100)}%',
                        (x, y-10), cv2.FONT_HERSHEY_DUPLEX, 0.6,  color, 2)

# %% [markdown]
# ####  Blob function
#
# OpenCV uses blob techniques to extract features from an image and allows detection. In order to be able to do forward propagation on our images or videos, we'll need to convert our images to **OpenCV blob's format**.

# %%
def convert_to_blob(input_frame, network, height, width):
    """ This function allow us to convert a frame/image into blob format for OpenCV DNN"""    
    blob = cv2.dnn.blobFromImage(input_frame, 1/255, (height,width), [0,0,0], 1, crop=False)
    network.setInput(blob)
    # get the YOLO output layers numbers (names), these layers will be useful for the detection part
    # the layer's name : yolo_82, yolo_94, yolo_106
    yoloLayers = network.getLayerNames()
    outputLayers = [(yoloLayers[i[0]-1]) for i in network.getUnconnectedOutLayers()]
    # Doing forward propagation with OpenCV
    outputs = network.forward(outputLayers)
    
    return outputs

# %% [markdown]
# ### Test on webcam cameras

# %%
cap_camera = cv2.VideoCapture(0)

network = neural_net
height, width = 320,320

while cap_camera.isOpened():
    success, camera_frames = cap_camera.read()
    # if 'camera_frames' is read correctly 'success' is True
    if not success:
        print("Can't receive frame (stream end?). Exiting ...")
        break
        
    # using convert_to_blob function : 
    outputs = convert_to_blob(camera_frames, network, height, width)    
    # apply object detection on the video file
    bounding_boxes, class_objects, confidence_probs = object_detection(outputs, camera_frames)   
    # perform non-max suppression
    indices = nms_bbox(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold)
    # draw the boxes
    box_drawing(camera_frames, indices, bounding_boxes, class_objects, confidence_probs, classNames, color=(0,255,255), thickness=2)
        
    cv2.imshow('Object Detection with a camera', camera_frames)
    
    if cv2.waitKey(1) == ord('q'):
        break
        
cap_camera.release()
cv2.destroyAllWindows()
# Out:
# Number of objects detected :  0
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  51 || y :  -7 || w :  594 || h : 483
#
# Bounding box coordinates in the frame :  x :  357 || y :  317 || w :  38 || h : 97
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  63 || y :  -2 || w :  582 || h : 502
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  91 || y :  3 || w :  553 || h : 487
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  95 || y :  5 || w :  547 || h : 483
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  92 || y :  6 || w :  549 || h : 481
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  77 || y :  9 || w :  555 || h : 481
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  72 || y :  3 || w :  557 || h : 492
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  61 || y :  5 || w :  568 || h : 487
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  61 || y :  6 || w :  553 || h : 491
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  11 || w :  548 || h : 482
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  62 || y :  16 || w :  542 || h : 472
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  16 || w :  537 || h : 473
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  61 || y :  18 || w :  541 || h : 467
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  63 || y :  16 || w :  536 || h : 474
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  68 || y :  19 || w :  527 || h : 473
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  62 || y :  16 || w :  541 || h : 476
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  60 || y :  16 || w :  542 || h : 476
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  61 || y :  14 || w :  542 || h : 477
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  58 || y :  17 || w :  545 || h : 476
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  61 || y :  15 || w :  542 || h : 477
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  62 || y :  15 || w :  539 || h : 481
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  62 || y :  16 || w :  540 || h : 477
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  19 || w :  546 || h : 469
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  58 || y :  17 || w :  547 || h : 475
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  54 || y :  16 || w :  554 || h : 478
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  55 || y :  16 || w :  550 || h : 478
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  56 || y :  18 || w :  552 || h : 475
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  62 || y :  19 || w :  543 || h : 470
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  56 || y :  21 || w :  552 || h : 472
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  56 || y :  20 || w :  552 || h : 474
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  53 || y :  19 || w :  557 || h : 475
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  57 || y :  21 || w :  551 || h : 472
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  56 || y :  20 || w :  555 || h : 472
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  54 || y :  22 || w :  556 || h : 473
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  58 || y :  22 || w :  552 || h : 471
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  60 || y :  15 || w :  549 || h : 479
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  55 || y :  17 || w :  557 || h : 476
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  63 || y :  22 || w :  543 || h : 469
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  18 || w :  538 || h : 476
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  56 || y :  16 || w :  554 || h : 479
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  57 || y :  21 || w :  555 || h : 472
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  18 || w :  547 || h : 477
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  58 || y :  17 || w :  553 || h : 476
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  62 || y :  16 || w :  545 || h : 478
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  57 || y :  20 || w :  550 || h : 474
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  17 || w :  550 || h : 476
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  54 || y :  15 || w :  556 || h : 479
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  54 || y :  11 || w :  557 || h : 486
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  53 || y :  10 || w :  563 || h : 484
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  61 || y :  6 || w :  559 || h : 487
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  8 || w :  548 || h : 482
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  57 || y :  5 || w :  558 || h : 489
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  6 || w :  557 || h : 487
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  5 || w :  559 || h : 491
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  58 || y :  4 || w :  568 || h : 487
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  2 || w :  560 || h : 490
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  55 || y :  4 || w :  572 || h : 489
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  62 || y :  1 || w :  567 || h : 468
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  68 || y :  -1 || w :  562 || h : 472
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  60 || y :  -1 || w :  575 || h : 473
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  68 || y :  -4 || w :  567 || h : 477
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  -6 || w :  575 || h : 480
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  69 || y :  -8 || w :  567 || h : 486
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  -2 || w :  572 || h : 475
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  68 || y :  0 || w :  567 || h : 469
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  65 || y :  -2 || w :  569 || h : 475
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  63 || y :  0 || w :  569 || h : 470
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  54 || y :  9 || w :  574 || h : 473
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  54 || y :  14 || w :  556 || h : 466
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  17 || y :  5 || w :  587 || h : 486
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  29 || y :  13 || w :  555 || h : 476
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  23 || y :  20 || w :  557 || h : 465
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  31 || y :  31 || w :  518 || h : 454
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  26 || y :  32 || w :  518 || h : 452
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  21 || y :  49 || w :  506 || h : 428
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  12 || y :  51 || w :  523 || h : 424
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  11 || y :  37 || w :  471 || h : 459
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  11 || y :  47 || w :  459 || h : 440
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  9 || y :  50 || w :  461 || h : 436
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  11 || y :  55 || w :  446 || h : 431
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  11 || y :  52 || w :  445 || h : 438
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  7 || y :  51 || w :  449 || h : 438
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  8 || y :  57 || w :  446 || h : 426
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  8 || y :  54 || w :  440 || h : 434
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -3 || y :  71 || w :  443 || h : 406
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -5 || y :  70 || w :  447 || h : 406
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  -6 || y :  65 || w :  443 || h : 415
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  8 || y :  56 || w :  441 || h : 430
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  8 || y :  57 || w :  447 || h : 429
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  10 || y :  54 || w :  447 || h : 433
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  5 || y :  55 || w :  466 || h : 429
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  8 || y :  54 || w :  461 || h : 435
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  9 || y :  50 || w :  469 || h : 439
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  10 || y :  48 || w :  471 || h : 441
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  10 || y :  44 || w :  480 || h : 447
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  4 || y :  40 || w :  492 || h : 449
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  9 || y :  50 || w :  518 || h : 429
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  11 || y :  39 || w :  523 || h : 450
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  22 || y :  37 || w :  505 || h : 450
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  19 || y :  19 || w :  533 || h : 476
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  25 || y :  21 || w :  529 || h : 474
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  32 || y :  13 || w :  547 || h : 484
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  37 || y :  13 || w :  544 || h : 483
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  28 || y :  14 || w :  564 || h : 480
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  55 || y :  10 || w :  554 || h : 483
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  47 || y :  3 || w :  582 || h : 493
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  50 || y :  2 || w :  578 || h : 496
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  54 || y :  0 || w :  577 || h : 500
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  58 || y :  0 || w :  576 || h : 501
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  62 || y :  -3 || w :  574 || h : 504
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  72 || y :  -4 || w :  562 || h : 505
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  58 || y :  -2 || w :  582 || h : 500
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  -5 || w :  583 || h : 507
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  62 || y :  -8 || w :  579 || h : 511
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  56 || y :  -4 || w :  587 || h : 504
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  64 || y :  -2 || w :  577 || h : 501
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  60 || y :  -6 || w :  584 || h : 508
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  -3 || w :  584 || h : 503
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  55 || y :  -6 || w :  592 || h : 509
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  -3 || w :  581 || h : 504
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  60 || y :  -1 || w :  578 || h : 500
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  59 || y :  -1 || w :  584 || h : 499
#
# Number of objects detected :  1
#
# Bounding box coordinates in the frame :  x :  58 || y :  0 || w :  580 || h : 498
